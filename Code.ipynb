# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import linearmodels.iv.model as lm
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col

# %%
df = pd.read_csv("Data-GP1-1.csv")
df
# Out:
#      Mon  Tue  Wed  Thu    Date  Stormy  Mixed         p         q  Rainy  \
# 0      1    0    0    0  911202       1      0 -0.430783  8.994421      1
# 1      0    1    0    0  911203       1      0  0.000000  7.707063      0
# 2      0    0    1    0  911204       0      1  0.072321  8.350194      1
# 3      0    0    0    1  911205       1      0  0.247139  8.656955      0
# 4      0    0    0    0  911206       1      0  0.664327  7.844241      0
# ..   ...  ...  ...  ...     ...     ...    ...       ...       ...    ...
# 106    1    0    0    0  920504       0      0 -0.798508  8.610683      0
# 107    0    1    0    0  920505       0      1 -0.087011  7.162397      0
# 108    0    0    1    0  920506       0      1  0.184922  7.362010      0
# 109    0    0    0    1  920507       0      1  0.223143  8.764053      0
# 110    0    0    0    0  920508       0      1  0.561118  8.328451      0
#
#      Cold      Wind
# 0       0  2.995732
# 1       0  2.995732
# 2       1  2.813411
# 3       1  3.036554
# 4       1  3.036554
# ..    ...       ...
# 106     0  2.862201
# 107     0  2.908721
# 108     0  2.862201
# 109     0  2.813411
# 110     0  2.862201
#
# [111 rows x 12 columns]

# %% [markdown]
# # Data Exploration - Correlation Analysis

# %% [markdown]
# ## Overall

# %%
df.corr().style.background_gradient(cmap='bwr_r', vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_099b4_row0_col0, #T_099b4_row1_col1, #T_099b4_row2_col2, #T_099b4_row3_col3, #T_099b4_row4_col4, #T_099b4_row5_col5, #T_099b4_row6_col6, #T_099b4_row7_col7, #T_099b4_row8_col8, #T_099b4_row9_col9, #T_099b4_row10_col10, #T_099b4_row11_col11 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_099b4_row0_col1, #T_099b4_row0_col3, #T_099b4_row1_col0, #T_099b4_row1_col2, #T_099b4_row2_col1, #T_099b4_row2_col3, #T_099b4_row3_col0, #T_099b4_row3_col2, #T_099b4_row4_col7, #T_099b4_row7_col4 {
#   background-color: #ffc0c0;
#   color: #000000;
# }
# #T_099b4_row0_col2, #T_099b4_row2_col0 {
#   background-color: #ffc4c4;
#   color: #000000;
# }
# #T_099b4_row0_col4, #T_099b4_row4_col0 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_099b4_row0_col5, #T_099b4_row5_col0, #T_099b4_row5_col9, #T_099b4_row9_col5, #T_099b4_row9_col10, #T_099b4_row10_col9 {
#   background-color: #e6e6ff;
#   color: #000000;
# }
# #T_099b4_row0_col6, #T_099b4_row3_col11, #T_099b4_row6_col0, #T_099b4_row11_col3 {
#   background-color: #ffe0e0;
#   color: #000000;
# }
# #T_099b4_row0_col7, #T_099b4_row7_col0 {
#   background-color: #ffecec;
#   color: #000000;
# }
# #T_099b4_row0_col8, #T_099b4_row8_col0 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_099b4_row0_col9, #T_099b4_row3_col5, #T_099b4_row3_col10, #T_099b4_row5_col3, #T_099b4_row9_col0, #T_099b4_row10_col3 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_099b4_row0_col10, #T_099b4_row1_col5, #T_099b4_row3_col4, #T_099b4_row4_col3, #T_099b4_row4_col6, #T_099b4_row5_col1, #T_099b4_row6_col4, #T_099b4_row10_col0 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_099b4_row0_col11, #T_099b4_row3_col8, #T_099b4_row8_col3, #T_099b4_row11_col0 {
#   background-color: #d4d4ff;
#   color: #000000;
# }
# #T_099b4_row1_col3, #T_099b4_row3_col1, #T_099b4_row8_col11, #T_099b4_row11_col8 {
#   background-color: #ffbcbc;
#   color: #000000;
# }
# #T_099b4_row1_col4, #T_099b4_row4_col1 {
#   background-color: #fff6f6;
#   color: #000000;
# }
# #T_099b4_row1_col6, #T_099b4_row6_col1 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_099b4_row1_col7, #T_099b4_row7_col1 {
#   background-color: #fffafa;
#   color: #000000;
# }
# #T_099b4_row1_col8, #T_099b4_row5_col8, #T_099b4_row8_col1, #T_099b4_row8_col5 {
#   background-color: #ffc6c6;
#   color: #000000;
# }
# #T_099b4_row1_col9, #T_099b4_row4_col9, #T_099b4_row9_col1, #T_099b4_row9_col4 {
#   background-color: #ffe4e4;
#   color: #000000;
# }
# #T_099b4_row1_col10, #T_099b4_row2_col4, #T_099b4_row4_col2, #T_099b4_row10_col1 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_099b4_row1_col11, #T_099b4_row11_col1 {
#   background-color: #e2e2ff;
#   color: #000000;
# }
# #T_099b4_row2_col5, #T_099b4_row5_col2 {
#   background-color: #fff2f2;
#   color: #000000;
# }
# #T_099b4_row2_col6, #T_099b4_row6_col2 {
#   background-color: #dedeff;
#   color: #000000;
# }
# #T_099b4_row2_col7, #T_099b4_row6_col8, #T_099b4_row7_col2, #T_099b4_row8_col6 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_099b4_row2_col8, #T_099b4_row8_col2 {
#   background-color: #ffc2c2;
#   color: #000000;
# }
# #T_099b4_row2_col9, #T_099b4_row7_col9, #T_099b4_row8_col9, #T_099b4_row9_col2, #T_099b4_row9_col7, #T_099b4_row9_col8 {
#   background-color: #f6f6ff;
#   color: #000000;
# }
# #T_099b4_row2_col10, #T_099b4_row6_col7, #T_099b4_row7_col6, #T_099b4_row9_col11, #T_099b4_row10_col2, #T_099b4_row11_col9 {
#   background-color: #eeeeff;
#   color: #000000;
# }
# #T_099b4_row2_col11, #T_099b4_row3_col9, #T_099b4_row6_col11, #T_099b4_row9_col3, #T_099b4_row11_col2, #T_099b4_row11_col6 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_099b4_row3_col6, #T_099b4_row6_col3 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_099b4_row3_col7, #T_099b4_row7_col3 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_099b4_row4_col5, #T_099b4_row5_col4 {
#   background-color: #ffd6d6;
#   color: #000000;
# }
# #T_099b4_row4_col8, #T_099b4_row8_col4 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_099b4_row4_col10, #T_099b4_row10_col4 {
#   background-color: #ffd4d4;
#   color: #000000;
# }
# #T_099b4_row4_col11, #T_099b4_row11_col4 {
#   background-color: #ffd0d0;
#   color: #000000;
# }
# #T_099b4_row5_col6, #T_099b4_row6_col5 {
#   background-color: #ff9292;
#   color: #000000;
# }
# #T_099b4_row5_col7, #T_099b4_row7_col5, #T_099b4_row7_col11, #T_099b4_row11_col7 {
#   background-color: #9898ff;
#   color: #f1f1f1;
# }
# #T_099b4_row5_col10, #T_099b4_row10_col5 {
#   background-color: #9a9aff;
#   color: #f1f1f1;
# }
# #T_099b4_row5_col11, #T_099b4_row11_col5 {
#   background-color: #3e3eff;
#   color: #f1f1f1;
# }
# #T_099b4_row6_col9, #T_099b4_row6_col10, #T_099b4_row9_col6, #T_099b4_row10_col6 {
#   background-color: #ffeaea;
#   color: #000000;
# }
# #T_099b4_row7_col8, #T_099b4_row8_col7 {
#   background-color: #ffb8b8;
#   color: #000000;
# }
# #T_099b4_row7_col10, #T_099b4_row10_col7 {
#   background-color: #c2c2ff;
#   color: #000000;
# }
# #T_099b4_row8_col10, #T_099b4_row10_col8 {
#   background-color: #ffdada;
#   color: #000000;
# }
# #T_099b4_row10_col11, #T_099b4_row11_col10 {
#   background-color: #8c8cff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_099b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_099b4_level0_col0" class="col_heading level0 col0" >Mon</th>
#       <th id="T_099b4_level0_col1" class="col_heading level0 col1" >Tue</th>
#       <th id="T_099b4_level0_col2" class="col_heading level0 col2" >Wed</th>
#       <th id="T_099b4_level0_col3" class="col_heading level0 col3" >Thu</th>
#       <th id="T_099b4_level0_col4" class="col_heading level0 col4" >Date</th>
#       <th id="T_099b4_level0_col5" class="col_heading level0 col5" >Stormy</th>
#       <th id="T_099b4_level0_col6" class="col_heading level0 col6" >Mixed</th>
#       <th id="T_099b4_level0_col7" class="col_heading level0 col7" >p</th>
#       <th id="T_099b4_level0_col8" class="col_heading level0 col8" >q</th>
#       <th id="T_099b4_level0_col9" class="col_heading level0 col9" >Rainy</th>
#       <th id="T_099b4_level0_col10" class="col_heading level0 col10" >Cold</th>
#       <th id="T_099b4_level0_col11" class="col_heading level0 col11" >Wind</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_099b4_level0_row0" class="row_heading level0 row0" >Mon</th>
#       <td id="T_099b4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_099b4_row0_col1" class="data row0 col1" >-0.246951</td>
#       <td id="T_099b4_row0_col2" class="data row0 col2" >-0.233333</td>
#       <td id="T_099b4_row0_col3" class="data row0 col3" >-0.246951</td>
#       <td id="T_099b4_row0_col4" class="data row0 col4" >-0.060778</td>
#       <td id="T_099b4_row0_col5" class="data row0 col5" >0.098818</td>
#       <td id="T_099b4_row0_col6" class="data row0 col6" >-0.121380</td>
#       <td id="T_099b4_row0_col7" class="data row0 col7" >-0.074936</td>
#       <td id="T_099b4_row0_col8" class="data row0 col8" >0.156964</td>
#       <td id="T_099b4_row0_col9" class="data row0 col9" >-0.025299</td>
#       <td id="T_099b4_row0_col10" class="data row0 col10" >0.018651</td>
#       <td id="T_099b4_row0_col11" class="data row0 col11" >0.165220</td>
#     </tr>
#     <tr>
#       <th id="T_099b4_level0_row1" class="row_heading level0 row1" >Tue</th>
#       <td id="T_099b4_row1_col0" class="data row1 col0" >-0.246951</td>
#       <td id="T_099b4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_099b4_row1_col2" class="data row1 col2" >-0.246951</td>
#       <td id="T_099b4_row1_col3" class="data row1 col3" >-0.261364</td>
#       <td id="T_099b4_row1_col4" class="data row1 col4" >-0.036667</td>
#       <td id="T_099b4_row1_col5" class="data row1 col5" >0.018126</td>
#       <td id="T_099b4_row1_col6" class="data row1 col6" >0.046049</td>
#       <td id="T_099b4_row1_col7" class="data row1 col7" >-0.018483</td>
#       <td id="T_099b4_row1_col8" class="data row1 col8" >-0.218871</td>
#       <td id="T_099b4_row1_col9" class="data row1 col9" >-0.104308</td>
#       <td id="T_099b4_row1_col10" class="data row1 col10" >0.062080</td>
#       <td id="T_099b4_row1_col11" class="data row1 col11" >0.117045</td>
#     </tr>
#     <tr>
#       <th id=

# %% [markdown]
# ## Correlation Analysis between q and other variables

# %%
q_corr =pd.DataFrame(df.corr()['q'])
q_corr.T.style.background_gradient(cmap='bwr_r', vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_31f2e_row0_col0 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_31f2e_row0_col1, #T_31f2e_row0_col5 {
#   background-color: #ffc6c6;
#   color: #000000;
# }
# #T_31f2e_row0_col2 {
#   background-color: #ffc2c2;
#   color: #000000;
# }
# #T_31f2e_row0_col3 {
#   background-color: #d4d4ff;
#   color: #000000;
# }
# #T_31f2e_row0_col4 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_31f2e_row0_col6 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_31f2e_row0_col7 {
#   background-color: #ffb8b8;
#   color: #000000;
# }
# #T_31f2e_row0_col8 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_31f2e_row0_col9 {
#   background-color: #f6f6ff;
#   color: #000000;
# }
# #T_31f2e_row0_col10 {
#   background-color: #ffdada;
#   color: #000000;
# }
# #T_31f2e_row0_col11 {
#   background-color: #ffbcbc;
#   color: #000000;
# }
# </style>
# <table id="T_31f2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31f2e_level0_col0" class="col_heading level0 col0" >Mon</th>
#       <th id="T_31f2e_level0_col1" class="col_heading level0 col1" >Tue</th>
#       <th id="T_31f2e_level0_col2" class="col_heading level0 col2" >Wed</th>
#       <th id="T_31f2e_level0_col3" class="col_heading level0 col3" >Thu</th>
#       <th id="T_31f2e_level0_col4" class="col_heading level0 col4" >Date</th>
#       <th id="T_31f2e_level0_col5" class="col_heading level0 col5" >Stormy</th>
#       <th id="T_31f2e_level0_col6" class="col_heading level0 col6" >Mixed</th>
#       <th id="T_31f2e_level0_col7" class="col_heading level0 col7" >p</th>
#       <th id="T_31f2e_level0_col8" class="col_heading level0 col8" >q</th>
#       <th id="T_31f2e_level0_col9" class="col_heading level0 col9" >Rainy</th>
#       <th id="T_31f2e_level0_col10" class="col_heading level0 col10" >Cold</th>
#       <th id="T_31f2e_level0_col11" class="col_heading level0 col11" >Wind</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31f2e_level0_row0" class="row_heading level0 row0" >q</th>
#       <td id="T_31f2e_row0_col0" class="data row0 col0" >0.156964</td>
#       <td id="T_31f2e_row0_col1" class="data row0 col1" >-0.218871</td>
#       <td id="T_31f2e_row0_col2" class="data row0 col2" >-0.234749</td>
#       <td id="T_31f2e_row0_col3" class="data row0 col3" >0.165607</td>
#       <td id="T_31f2e_row0_col4" class="data row0 col4" >-0.066379</td>
#       <td id="T_31f2e_row0_col5" class="data row0 col5" >-0.222636</td>
#       <td id="T_31f2e_row0_col6" class="data row0 col6" >-0.008908</td>
#       <td id="T_31f2e_row0_col7" class="data row0 col7" >-0.278530</td>
#       <td id="T_31f2e_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_31f2e_row0_col9" class="data row0 col9" >0.033979</td>
#       <td id="T_31f2e_row0_col10" class="data row0 col10" >-0.142820</td>
#       <td id="T_31f2e_row0_col11" class="data row0 col11" >-0.263995</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Weak relationship: `Tue`, `Wed`, `Stormy`, `p`, `Wind`
# - Others have nearly no relationship with `q`

# %% [markdown]
# ## Correlation Analysis between p and other variables

# %%
p_corr =pd.DataFrame(df.corr()['p']).T
p_corr.style.background_gradient(cmap='bwr_r', vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_e008e_row0_col0 {
#   background-color: #ffecec;
#   color: #000000;
# }
# #T_e008e_row0_col1 {
#   background-color: #fffafa;
#   color: #000000;
# }
# #T_e008e_row0_col2 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_e008e_row0_col3 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_e008e_row0_col4 {
#   background-color: #ffc0c0;
#   color: #000000;
# }
# #T_e008e_row0_col5, #T_e008e_row0_col11 {
#   background-color: #9898ff;
#   color: #f1f1f1;
# }
# #T_e008e_row0_col6 {
#   background-color: #eeeeff;
#   color: #000000;
# }
# #T_e008e_row0_col7 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_e008e_row0_col8 {
#   background-color: #ffb8b8;
#   color: #000000;
# }
# #T_e008e_row0_col9 {
#   background-color: #f6f6ff;
#   color: #000000;
# }
# #T_e008e_row0_col10 {
#   background-color: #c2c2ff;
#   color: #000000;
# }
# </style>
# <table id="T_e008e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e008e_level0_col0" class="col_heading level0 col0" >Mon</th>
#       <th id="T_e008e_level0_col1" class="col_heading level0 col1" >Tue</th>
#       <th id="T_e008e_level0_col2" class="col_heading level0 col2" >Wed</th>
#       <th id="T_e008e_level0_col3" class="col_heading level0 col3" >Thu</th>
#       <th id="T_e008e_level0_col4" class="col_heading level0 col4" >Date</th>
#       <th id="T_e008e_level0_col5" class="col_heading level0 col5" >Stormy</th>
#       <th id="T_e008e_level0_col6" class="col_heading level0 col6" >Mixed</th>
#       <th id="T_e008e_level0_col7" class="col_heading level0 col7" >p</th>
#       <th id="T_e008e_level0_col8" class="col_heading level0 col8" >q</th>
#       <th id="T_e008e_level0_col9" class="col_heading level0 col9" >Rainy</th>
#       <th id="T_e008e_level0_col10" class="col_heading level0 col10" >Cold</th>
#       <th id="T_e008e_level0_col11" class="col_heading level0 col11" >Wind</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e008e_level0_row0" class="row_heading level0 row0" >p</th>
#       <td id="T_e008e_row0_col0" class="data row0 col0" >-0.074936</td>
#       <td id="T_e008e_row0_col1" class="data row0 col1" >-0.018483</td>
#       <td id="T_e008e_row0_col2" class="data row0 col2" >-0.009366</td>
#       <td id="T_e008e_row0_col3" class="data row0 col3" >0.083350</td>
#       <td id="T_e008e_row0_col4" class="data row0 col4" >-0.244170</td>
#       <td id="T_e008e_row0_col5" class="data row0 col5" >0.399417</td>
#       <td id="T_e008e_row0_col6" class="data row0 col6" >0.065993</td>
#       <td id="T_e008e_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_e008e_row0_col8" class="data row0 col8" >-0.278530</td>
#       <td id="T_e008e_row0_col9" class="data row0 col9" >0.036653</td>
#       <td id="T_e008e_row0_col10" class="data row0 col10" >0.241886</td>
#       <td id="T_e008e_row0_col11" class="data row0 col11" >0.405123</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Low correlation: `Date`, `q`, `Cold`
# - Moderate correlation/Substantial relationship: `Stormy`, `Wind`
# - We can hypothesize both `Stormy` and `Wind` can be the potential instrumental variables

# %% [markdown]
# ## Correlation Analysis between Stormy and other variables

# %%
stormy_corr =pd.DataFrame(df.corr()['Stormy'])
stormy_corr.T.style.background_gradient(cmap='bwr_r', vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_1137d_row0_col0, #T_1137d_row0_col9 {
#   background-color: #e6e6ff;
#   color: #000000;
# }
# #T_1137d_row0_col1 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_1137d_row0_col2 {
#   background-color: #fff2f2;
#   color: #000000;
# }
# #T_1137d_row0_col3 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_1137d_row0_col4 {
#   background-color: #ffd6d6;
#   color: #000000;
# }
# #T_1137d_row0_col5 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_1137d_row0_col6 {
#   background-color: #ff9292;
#   color: #000000;
# }
# #T_1137d_row0_col7 {
#   background-color: #9898ff;
#   color: #f1f1f1;
# }
# #T_1137d_row0_col8 {
#   background-color: #ffc6c6;
#   color: #000000;
# }
# #T_1137d_row0_col10 {
#   background-color: #9a9aff;
#   color: #f1f1f1;
# }
# #T_1137d_row0_col11 {
#   background-color: #3e3eff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1137d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1137d_level0_col0" class="col_heading level0 col0" >Mon</th>
#       <th id="T_1137d_level0_col1" class="col_heading level0 col1" >Tue</th>
#       <th id="T_1137d_level0_col2" class="col_heading level0 col2" >Wed</th>
#       <th id="T_1137d_level0_col3" class="col_heading level0 col3" >Thu</th>
#       <th id="T_1137d_level0_col4" class="col_heading level0 col4" >Date</th>
#       <th id="T_1137d_level0_col5" class="col_heading level0 col5" >Stormy</th>
#       <th id="T_1137d_level0_col6" class="col_heading level0 col6" >Mixed</th>
#       <th id="T_1137d_level0_col7" class="col_heading level0 col7" >p</th>
#       <th id="T_1137d_level0_col8" class="col_heading level0 col8" >q</th>
#       <th id="T_1137d_level0_col9" class="col_heading level0 col9" >Rainy</th>
#       <th id="T_1137d_level0_col10" class="col_heading level0 col10" >Cold</th>
#       <th id="T_1137d_level0_col11" class="col_heading level0 col11" >Wind</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1137d_level0_row0" class="row_heading level0 row0" >Stormy</th>
#       <td id="T_1137d_row0_col0" class="data row0 col0" >0.098818</td>
#       <td id="T_1137d_row0_col1" class="data row0 col1" >0.018126</td>
#       <td id="T_1137d_row0_col2" class="data row0 col2" >-0.053526</td>
#       <td id="T_1137d_row0_col3" class="data row0 col3" >-0.030946</td>
#       <td id="T_1137d_row0_col4" class="data row0 col4" >-0.159531</td>
#       <td id="T_1137d_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_1137d_row0_col6" class="data row0 col6" >-0.422917</td>
#       <td id="T_1137d_row0_col7" class="data row0 col7" >0.399417</td>
#       <td id="T_1137d_row0_col8" class="data row0 col8" >-0.222636</td>
#       <td id="T_1137d_row0_col9" class="data row0 col9" >0.097708</td>
#       <td id="T_1137d_row0_col10" class="data row0 col10" >0.392061</td>
#       <td id="T_1137d_row0_col11" class="data row0 col11" >0.753123</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Low correlation: `q`
# - Moderate correlation: `Mixed`, `p`, `Cold`
# - Strong correlation: `Wind`

# %% [markdown]
# ## Correlation Analysis between Wind and other variables

# %%
wind_corr =pd.DataFrame(df.corr()['Wind'])
wind_corr.T.style.background_gradient(cmap='bwr_r', vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_ab716_row0_col0 {
#   background-color: #d4d4ff;
#   color: #000000;
# }
# #T_ab716_row0_col1 {
#   background-color: #e2e2ff;
#   color: #000000;
# }
# #T_ab716_row0_col2, #T_ab716_row0_col6 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_ab716_row0_col3 {
#   background-color: #ffe0e0;
#   color: #000000;
# }
# #T_ab716_row0_col4 {
#   background-color: #ffd0d0;
#   color: #000000;
# }
# #T_ab716_row0_col5 {
#   background-color: #3e3eff;
#   color: #f1f1f1;
# }
# #T_ab716_row0_col7 {
#   background-color: #9898ff;
#   color: #f1f1f1;
# }
# #T_ab716_row0_col8 {
#   background-color: #ffbcbc;
#   color: #000000;
# }
# #T_ab716_row0_col9 {
#   background-color: #eeeeff;
#   color: #000000;
# }
# #T_ab716_row0_col10 {
#   background-color: #8c8cff;
#   color: #f1f1f1;
# }
# #T_ab716_row0_col11 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ab716">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab716_level0_col0" class="col_heading level0 col0" >Mon</th>
#       <th id="T_ab716_level0_col1" class="col_heading level0 col1" >Tue</th>
#       <th id="T_ab716_level0_col2" class="col_heading level0 col2" >Wed</th>
#       <th id="T_ab716_level0_col3" class="col_heading level0 col3" >Thu</th>
#       <th id="T_ab716_level0_col4" class="col_heading level0 col4" >Date</th>
#       <th id="T_ab716_level0_col5" class="col_heading level0 col5" >Stormy</th>
#       <th id="T_ab716_level0_col6" class="col_heading level0 col6" >Mixed</th>
#       <th id="T_ab716_level0_col7" class="col_heading level0 col7" >p</th>
#       <th id="T_ab716_level0_col8" class="col_heading level0 col8" >q</th>
#       <th id="T_ab716_level0_col9" class="col_heading level0 col9" >Rainy</th>
#       <th id="T_ab716_level0_col10" class="col_heading level0 col10" >Cold</th>
#       <th id="T_ab716_level0_col11" class="col_heading level0 col11" >Wind</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab716_level0_row0" class="row_heading level0 row0" >Wind</th>
#       <td id="T_ab716_row0_col0" class="data row0 col0" >0.165220</td>
#       <td id="T_ab716_row0_col1" class="data row0 col1" >0.117045</td>
#       <td id="T_ab716_row0_col2" class="data row0 col2" >-0.045354</td>
#       <td id="T_ab716_row0_col3" class="data row0 col3" >-0.119755</td>
#       <td id="T_ab716_row0_col4" class="data row0 col4" >-0.186811</td>
#       <td id="T_ab716_row0_col5" class="data row0 col5" >0.753123</td>
#       <td id="T_ab716_row0_col6" class="data row0 col6" >-0.046567</td>
#       <td id="T_ab716_row0_col7" class="data row0 col7" >0.405123</td>
#       <td id="T_ab716_row0_col8" class="data row0 col8" >-0.263995</td>
#       <td id="T_ab716_row0_col9" class="data row0 col9" >0.065632</td>
#       <td id="T_ab716_row0_col10" class="data row0 col10" >0.450201</td>
#       <td id="T_ab716_row0_col11" class="data row0 col11" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - low correlation: `q`
# - Moderate correlation: `p`, `Cold`
# - Strong correlation: `Stormy`

# %% [markdown]
# ## Correlation Among Weekdays

# %%
week_corr = df.corr()[:4].style.background_gradient(cmap='bwr_r', vmin = -1, vmax = 1)
week_corr
# Out:
# <style type="text/css">
# #T_103ab_row0_col0, #T_103ab_row1_col1, #T_103ab_row2_col2, #T_103ab_row3_col3 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_103ab_row0_col1, #T_103ab_row0_col3, #T_103ab_row1_col0, #T_103ab_row1_col2, #T_103ab_row2_col1, #T_103ab_row2_col3, #T_103ab_row3_col0, #T_103ab_row3_col2 {
#   background-color: #ffc0c0;
#   color: #000000;
# }
# #T_103ab_row0_col2, #T_103ab_row2_col0 {
#   background-color: #ffc4c4;
#   color: #000000;
# }
# #T_103ab_row0_col4 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_103ab_row0_col5 {
#   background-color: #e6e6ff;
#   color: #000000;
# }
# #T_103ab_row0_col6, #T_103ab_row3_col11 {
#   background-color: #ffe0e0;
#   color: #000000;
# }
# #T_103ab_row0_col7 {
#   background-color: #ffecec;
#   color: #000000;
# }
# #T_103ab_row0_col8 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_103ab_row0_col9, #T_103ab_row3_col5, #T_103ab_row3_col10 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_103ab_row0_col10, #T_103ab_row1_col5, #T_103ab_row3_col4 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_103ab_row0_col11, #T_103ab_row3_col8 {
#   background-color: #d4d4ff;
#   color: #000000;
# }
# #T_103ab_row1_col3, #T_103ab_row3_col1 {
#   background-color: #ffbcbc;
#   color: #000000;
# }
# #T_103ab_row1_col4 {
#   background-color: #fff6f6;
#   color: #000000;
# }
# #T_103ab_row1_col6 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_103ab_row1_col7 {
#   background-color: #fffafa;
#   color: #000000;
# }
# #T_103ab_row1_col8 {
#   background-color: #ffc6c6;
#   color: #000000;
# }
# #T_103ab_row1_col9 {
#   background-color: #ffe4e4;
#   color: #000000;
# }
# #T_103ab_row1_col10, #T_103ab_row2_col4 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_103ab_row1_col11 {
#   background-color: #e2e2ff;
#   color: #000000;
# }
# #T_103ab_row2_col5 {
#   background-color: #fff2f2;
#   color: #000000;
# }
# #T_103ab_row2_col6 {
#   background-color: #dedeff;
#   color: #000000;
# }
# #T_103ab_row2_col7 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_103ab_row2_col8 {
#   background-color: #ffc2c2;
#   color: #000000;
# }
# #T_103ab_row2_col9 {
#   background-color: #f6f6ff;
#   color: #000000;
# }
# #T_103ab_row2_col10 {
#   background-color: #eeeeff;
#   color: #000000;
# }
# #T_103ab_row2_col11, #T_103ab_row3_col9 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_103ab_row3_col6 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_103ab_row3_col7 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# </style>
# <table id="T_103ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_103ab_level0_col0" class="col_heading level0 col0" >Mon</th>
#       <th id="T_103ab_level0_col1" class="col_heading level0 col1" >Tue</th>
#       <th id="T_103ab_level0_col2" class="col_heading level0 col2" >Wed</th>
#       <th id="T_103ab_level0_col3" class="col_heading level0 col3" >Thu</th>
#       <th id="T_103ab_level0_col4" class="col_heading level0 col4" >Date</th>
#       <th id="T_103ab_level0_col5" class="col_heading level0 col5" >Stormy</th>
#       <th id="T_103ab_level0_col6" class="col_heading level0 col6" >Mixed</th>
#       <th id="T_103ab_level0_col7" class="col_heading level0 col7" >p</th>
#       <th id="T_103ab_level0_col8" class="col_heading level0 col8" >q</th>
#       <th id="T_103ab_level0_col9" class="col_heading level0 col9" >Rainy</th>
#       <th id="T_103ab_level0_col10" class="col_heading level0 col10" >Cold</th>
#       <th id="T_103ab_level0_col11" class="col_heading level0 col11" >Wind</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_103ab_level0_row0" class="row_heading level0 row0" >Mon</th>
#       <td id="T_103ab_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_103ab_row0_col1" class="data row0 col1" >-0.246951</td>
#       <td id="T_103ab_row0_col2" class="data row0 col2" >-0.233333</td>
#       <td id="T_103ab_row0_col3" class="data row0 col3" >-0.246951</td>
#       <td id="T_103ab_row0_col4" class="data row0 col4" >-0.060778</td>
#       <td id="T_103ab_row0_col5" class="data row0 col5" >0.098818</td>
#       <td id="T_103ab_row0_col6" class="data row0 col6" >-0.121380</td>
#       <td id="T_103ab_row0_col7" class="data row0 col7" >-0.074936</td>
#       <td id="T_103ab_row0_col8" class="data row0 col8" >0.156964</td>
#       <td id="T_103ab_row0_col9" class="data row0 col9" >-0.025299</td>
#       <td id="T_103ab_row0_col10" class="data row0 col10" >0.018651</td>
#       <td id="T_103ab_row0_col11" class="data row0 col11" >0.165220</td>
#     </tr>
#     <tr>
#       <th id="T_103ab_level0_row1" class="row_heading level0 row1" >Tue</th>
#       <td id="T_103ab_row1_col0" class="data row1 col0" >-0.246951</td>
#       <td id="T_103ab_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_103ab_row1_col2" class="data row1 col2" >-0.246951</td>
#       <td id="T_103ab_row1_col3" class="data row1 col3" >-0.261364</td>
#       <td id="T_103ab_row1_col4" class="data row1 col4" >-0.036667</td>
#       <td id="T_103ab_row1_col5" class="data row1 col5" >0.018126</td>
#       <td id="T_103ab_row1_col6" class="data row1 col6" >0.046049</td>
#       <td id="T_103ab_row1_col7" class="data row1 col7" >-0.018483</td>
#       <td id="T_103ab_row1_col8" class="data row1 col8" >-0.218871</td>
#       <td id="T_103ab_row1_col9" class="data row1 col9" >-0.104308</td>
#       <td id="T_103ab_row1_col10" class="data row1 col10" >0.062080</td>
#       <td id="T_103ab_row1_col11" class="data row1 col11" >0.117045</td>
#     </tr>
#     <tr>
#       <th id="T_103ab_level0_row2" class="row_heading level0 row2" >Wed</th>
#       <td id="T_103ab_row2_col0" class="data row2 col0" >-0.233333</td>
#       <td id="T_103ab_row2_col1" class="data row2 col1" >-0.246951</td>
#       <td id="T_103ab_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_103ab_row2_col3" class="data row2 col3" >-0.246951</td>
#       <td id="T_103ab_row2_col4" class="data row2 col4" >0.057674</td>
#       <td id="T_103ab_row2_col5" class="data row2 col5" >-0.053526</td>
#       <td id="T_103ab_row2_col6" class="data row2 col6" >0.128124</td>
#       <td id="T_103ab_row2_col7" class="data row2 col7" >-0.009366</td>
#       <td id="T_103ab_row2_col8" class="data row2 col8" >-0.234749</td>
#       <td id="T_103ab_row2_col9" class="data row2 col9" >0.037105</td>
#       <td id="T_103ab_row2_col10" class="data row2 col10" >0.064657</td>
#       <td id="T_103ab_row2_col11" class="data row2 col11" >-0.045354</td>
#     </tr>
#     <tr>
#       <th id="T_103ab_level0_row3" class="row_heading level0 row3" >Thu</th>
#       <td id="T_103ab_row3_col0" class="data row3 col0" >-0.246951</td>
#       <td id="T_103ab_row3_col1" class="data row3 col1" >-0.261364</td>
#       <td id="T_103ab_row3_col2" class="data row3 col2" >-0.246951</td>
#       <td id="T_103ab_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_103ab_row3_col4" class="data row3 col4" >0.019542</td>
#       <td id="T_103ab_row3_col5" class="data row3 col5" >-0.030946</td>
#       <td id="T_103ab_row3_col6" class="data row3 col6" >-0.002172</td>
#       <td id="T_103ab_row3_col7" class="data row3 col7" >0.083350</td>
#       <td id="T_103ab_row3_col8" class="data row3 col8" >0.165607</td>
#       <td id="T_103ab_row3_col9" class="data row3 col9" >-0.044005</td>
#       <td id="T_103ab_row3_col10" class="data row3 col10" >-0.026835</td>
#       <td id="T_103ab_row3_col11" class="data row3 col11" >-0.119755</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Weekday are definitely interdependent on one another because of the nature of binary variables

# %% [markdown]
# ## Findings:
# - To prevent multi-collinearity, `Wind` and `Stormy` should not be used together
# - `Mixed`, `Cold`  may not be good controls due to their moderate correlations with `Stormy` and `Wind`

# %% [markdown]
# # OLS Regression

# %% [markdown]
# ## Simple Linear Regression as the Baseline Demand

# %%
y = df['q']
X = df['p']
X = sm.add_constant(X)
baseline_model = sm.OLS(y,X).fit()
print(baseline_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      q   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     9.167
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):            0.00308
# Time:                        15:31:05   Log-Likelihood:                -119.35
# No. Observations:                 111   AIC:                             242.7
# Df Residuals:                     109   BIC:                             248.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.4187      0.076    110.445      0.000       8.268       8.570
# p             -0.5409      0.179     -3.028      0.003      -0.895      -0.187
# ==============================================================================
# Omnibus:                       12.064   Durbin-Watson:                   1.556
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.644
# Skew:                          -0.796   Prob(JB):                      0.00180
# Kurtosis:                       3.448   Cond. No.                         2.74
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - Although price is significant with p-value <0.05, low R-squared value indicates that solely price is not explaining much in the variation of the quantity

# %% [markdown]
# ## Multilinear regression for Control Variable Selection

# %%
#Baseline
m1 = smf.ols('q ~ p',data=df, ).fit()

#Based on correlation analysis
m2 = smf.ols('q ~ p + Stormy  + Tue + Wed ',data=df).fit()

#Only stormy to prevent multicollinearity
m3 = smf.ols('q ~ p + Stormy  + Mon + Tue + Wed + Thu + Mixed + Rainy + Cold',data=df).fit()

#Include all the variables in the dataset
m4 = smf.ols('q ~ p + Stormy + Wind + Mon + Tue + Wed + Thu + Mixed + Rainy + Cold',data=df).fit()

print("Dependent variable: q", summary_col([m1,m2, m3, m4], float_format='%.3f',stars=True,regressor_order=['Intercept', 'p', 'Stormy', 'Wind', 'Mon', 'Tue', 'Wed', 'Thu', 'Mixed', 'Rainy', 'Cold'], model_names = ['I', 'II', 'III', 'IV']))
# Out:
# Dependent variable: q
# ======================================================
#                    I         II       III        IV
# ------------------------------------------------------
# Intercept      8.419***  8.730***  8.665***  10.114***
#                (0.076)   (0.104)   (0.181)   (1.529)
# p              -0.541*** -0.447**  -0.449**  -0.434**
#                (0.179)   (0.180)   (0.195)   (0.195)
# Stormy                   -0.232    -0.241    -0.044
#                          (0.151)   (0.189)   (0.280)
# Wind                                         -0.543
#                                              (0.570)
# Mon                                0.061     0.103
#                                    (0.207)   (0.212)
# Tue                      -0.545*** -0.489**  -0.458**
#                          (0.160)   (0.204)   (0.207)
# Wed                      -0.600*** -0.554*** -0.553***
#                          (0.165)   (0.208)   (0.208)
# Thu                                0.087     0.079
#                                    (0.201)   (0.201)
# Mixed                              0.003     0.078
#                                    (0.162)   (0.181)
# Rainy                              0.085     0.089
#                                    (0.178)   (0.178)
# Cold                               0.005     0.037
#                                    (0.142)   (0.146)
# R-squared      0.078     0.236     0.239     0.246
# R-squared Adj. 0.069     0.207     0.171     0.170
# ======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# # 2SLS Regression

# %% [markdown]
# ## The baseline & statistically best model : Stormy as IV without any control

# %%
y = df['p']
X = df['Stormy']
X = sm.add_constant(X)
baseline_stage1 = sm.OLS(y,X).fit()
print(baseline_stage1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      p   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     20.69
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):           1.41e-05
# Time:                        15:39:56   Log-Likelihood:                -40.516
# No. Observations:                 111   AIC:                             85.03
# Df Residuals:                     109   BIC:                             90.45
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2903      0.040     -7.336      0.000      -0.369      -0.212
# Stormy         0.3353      0.074      4.549      0.000       0.189       0.481
# ==============================================================================
# Omnibus:                        0.924   Durbin-Watson:                   0.634
# Prob(Omnibus):                  0.630   Jarque-Bera (JB):                1.036
# Skew:                          -0.188   Prob(JB):                        0.596
# Kurtosis:                       2.712   Cond. No.                         2.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
p_hat = baseline_stage1.predict(X)
df['p_hat'] = p_hat

# %%
y = df['q']
X = df['p_hat']
X = sm.add_constant(X)
baseline_stage2 = sm.OLS(y,X).fit()
print(baseline_stage2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      q   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     5.685
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):             0.0188
# Time:                        15:40:01   Log-Likelihood:                -121.01
# No. Observations:                 111   AIC:                             246.0
# Df Residuals:                     109   BIC:                             251.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.3138      0.112     74.406      0.000       8.092       8.535
# p_hat         -1.0824      0.454     -2.384      0.019      -1.982      -0.183
# ==============================================================================
# Omnibus:                       12.308   Durbin-Watson:                   1.625
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.886
# Skew:                          -0.787   Prob(JB):                      0.00159
# Kurtosis:                       3.557   Cond. No.                         6.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## The more generalized model: Stormy as IV, all Weekdays as Controls

# %%
Z = df['p']
X = df[['Stormy', 'Mon', 'Tue', 'Wed', 'Thu']]
X = sm.add_constant(X)
gen_stage1 = sm.OLS(Z,X).fit()
print(gen_stage1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      p   R-squared:                       0.179
# Model:                            OLS   Adj. R-squared:                  0.140
# Method:                 Least Squares   F-statistic:                     4.575
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):           0.000816
# Time:                        15:43:03   Log-Likelihood:                -39.223
# No. Observations:                 111   AIC:                             90.45
# Df Residuals:                     105   BIC:                             106.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2717      0.076     -3.557      0.001      -0.423      -0.120
# Stormy         0.3464      0.075      4.639      0.000       0.198       0.494
# Mon           -0.1129      0.107     -1.052      0.295      -0.326       0.100
# Tue           -0.0411      0.105     -0.394      0.695      -0.248       0.166
# Wed           -0.0118      0.107     -0.111      0.912      -0.224       0.200
# Thu            0.0496      0.104      0.475      0.636      -0.157       0.257
# ==============================================================================
# Omnibus:                        1.265   Durbin-Watson:                   0.632
# Prob(Omnibus):                  0.531   Jarque-Bera (JB):                1.352
# Skew:                          -0.222   Prob(JB):                        0.509
# Kurtosis:                       2.691   Cond. No.                         5.98
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
p_hat = gen_stage1.predict(X)
df['p_hat'] = p_hat

# %%
Y = df['q']
X = df[['p_hat','Mon', 'Tue', 'Wed', 'Thu']]
X = sm.add_constant(X)
gen_stage2= sm.OLS(Y,X).fit()
print(gen_stage2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      q   R-squared:                       0.193
# Model:                            OLS   Adj. R-squared:                  0.155
# Method:                 Least Squares   F-statistic:                     5.034
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):           0.000356
# Time:                        15:43:04   Log-Likelihood:                -111.90
# No. Observations:                 111   AIC:                             235.8
# Df Residuals:                     105   BIC:                             252.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.5059      0.161     52.882      0.000       8.187       8.825
# p_hat         -1.1194      0.415     -2.698      0.008      -1.942      -0.297
# Mon           -0.0254      0.208     -0.122      0.903      -0.438       0.387
# Tue           -0.5308      0.201     -2.636      0.010      -0.930      -0.132
# Wed           -0.5664      0.206     -2.750      0.007      -0.975      -0.158
# Thu            0.1093      0.202      0.541      0.590      -0.291       0.510
# ==============================================================================
# Omnibus:                       15.952   Durbin-Watson:                   1.546
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.150
# Skew:                          -0.811   Prob(JB):                     6.95e-05
# Kurtosis:                       4.228   Cond. No.                         7.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Wu-Hausman Test

# %%
mlr2 = lm.IV2SLS(dependent=df['q'], exog= df[['Mon', 'Tue', 'Wed', 'Thu']], endog=df['p'], instruments=df['Stormy']).fit(cov_type="homoskedastic", debiased=True)
mlr2.wu_hausman()
# Out:
# Wu-Hausman test of exogeneity
# H0: All endogenous variables are exogenous
# Statistic: 12.5483
# P-value: 0.0006
# Distributed: F(1,105)
# WaldTestStatistic, id: 0x132c999d0

# %% [markdown]
# # Trial Models not used in the Final Research Paper

# %% [markdown]
# ## Stormy as IV + Tue, Wed as controls
# - F-stat in stage 1 is lower than our baseline 2SlS model

# %%
Z = df['p']
X = df[['Stormy','Tue','Wed']]
X = sm.add_constant(X)
model = sm.OLS(Z,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      p   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.137
# Method:                 Least Squares   F-statistic:                     6.805
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):           0.000305
# Time:                        15:43:08   Log-Likelihood:                -40.470
# No. Observations:                 111   AIC:                             88.94
# Df Residuals:                     107   BIC:                             99.78
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2869      0.049     -5.889      0.000      -0.384      -0.190
# Stormy         0.3359      0.074      4.511      0.000       0.188       0.484
# Tue           -0.0227      0.086     -0.265      0.791      -0.193       0.147
# Wed            0.0059      0.089      0.066      0.947      -0.170       0.182
# ==============================================================================
# Omnibus:                        0.933   Durbin-Watson:                   0.636
# Prob(Omnibus):                  0.627   Jarque-Bera (JB):                1.044
# Skew:                          -0.188   Prob(JB):                        0.593
# Kurtosis:                       2.711   Cond. No.                         3.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
p_hat = model.predict(X)
df['p_hat'] = p_hat

# %%
Y = df['q']
X = df[['p_hat', 'Tue','Wed']]
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      q   R-squared:                       0.192
# Model:                            OLS   Adj. R-squared:                  0.169
# Method:                 Least Squares   F-statistic:                     8.449
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):           4.33e-05
# Time:                        15:43:10   Log-Likelihood:                -112.03
# No. Observations:                 111   AIC:                             232.1
# Df Residuals:                     107   BIC:                             242.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.5321      0.114     74.716      0.000       8.306       8.758
# p_hat         -1.1376      0.422     -2.693      0.008      -1.975      -0.300
# Tue           -0.5607      0.164     -3.426      0.001      -0.885      -0.236
# Wed           -0.5962      0.169     -3.523      0.001      -0.932      -0.261
# ==============================================================================
# Omnibus:                       14.994   Durbin-Watson:                   1.557
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               17.521
# Skew:                          -0.785   Prob(JB):                     0.000157
# Kurtosis:                       4.151   Cond. No.                         7.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Stormy as IV + Tue as control
# - F-stat in stage 1 is lower than our baseline 2SlS model

# %%
Z = df['p']
X = df[['Stormy', 'Tue']]
X = sm.add_constant(X)
model = sm.OLS(Z,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      p   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     10.30
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):           8.05e-05
# Time:                        15:43:12   Log-Likelihood:                -40.472
# No. Observations:                 111   AIC:                             86.94
# Df Residuals:                     108   BIC:                             95.07
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2854      0.043     -6.618      0.000      -0.371      -0.200
# Stormy         0.3357      0.074      4.534      0.000       0.189       0.482
# Tue           -0.0241      0.083     -0.292      0.771      -0.188       0.140
# ==============================================================================
# Omnibus:                        0.971   Durbin-Watson:                   0.636
# Prob(Omnibus):                  0.615   Jarque-Bera (JB):                1.080
# Skew:                          -0.191   Prob(JB):                        0.583
# Kurtosis:                       2.705   Cond. No.                         2.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
p_hat = model.predict(X)
df['p_hat'] = p_hat

# %%
Y = df['q']
X = df[['p_hat','Tue']]
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      q   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     5.717
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):            0.00436
# Time:                        15:43:14   Log-Likelihood:                -118.24
# No. Observations:                 111   AIC:                             242.5
# Df Residuals:                     108   BIC:                             250.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.4041      0.114     74.012      0.000       8.179       8.629
# p_hat         -1.0622      0.444     -2.390      0.019      -1.943      -0.181
# Tue           -0.4171      0.167     -2.500      0.014      -0.748      -0.086
# ==============================================================================
# Omnibus:                       14.892   Durbin-Watson:                   1.681
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.863
# Skew:                          -0.811   Prob(JB):                     0.000218
# Kurtosis:                       4.008   Cond. No.                         6.99
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Stormy as IV + Wed as Control
# - F-stat in stage 1 is lower than our baseline 2SlS model

# %%
Z = df['p']
X = df[['Stormy','Wed']]
X = sm.add_constant(X)
model = sm.OLS(Z,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      p   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.144
# Method:                 Least Squares   F-statistic:                     10.26
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):           8.32e-05
# Time:                        15:43:16   Log-Likelihood:                -40.506
# No. Observations:                 111   AIC:                             87.01
# Df Residuals:                     108   BIC:                             95.14
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2927      0.043     -6.747      0.000      -0.379      -0.207
# Stormy         0.3358      0.074      4.529      0.000       0.189       0.483
# Wed            0.0117      0.086      0.136      0.892      -0.158       0.182
# ==============================================================================
# Omnibus:                        0.857   Durbin-Watson:                   0.633
# Prob(Omnibus):                  0.651   Jarque-Bera (JB):                0.972
# Skew:                          -0.182   Prob(JB):                        0.615
# Kurtosis:                       2.723   Cond. No.                         2.85
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
p_hat = model.predict(X)
df['p_hat'] = p_hat

# %%
Y = df['q']
X = df[['p_hat','Wed']]
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      q   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                  0.094
# Method:                 Least Squares   F-statistic:                     6.714
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):            0.00178
# Time:                        15:43:17   Log-Likelihood:                -117.32
# No. Observations:                 111   AIC:                             240.6
# Df Residuals:                     108   BIC:                             248.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.3874      0.113     74.405      0.000       8.164       8.611
# p_hat         -1.1449      0.441     -2.596      0.011      -2.019      -0.271
# Wed           -0.4529      0.171     -2.647      0.009      -0.792      -0.114
# ==============================================================================
# Omnibus:                       12.909   Durbin-Watson:                   1.612
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.680
# Skew:                          -0.812   Prob(JB):                      0.00107
# Kurtosis:                       3.565   Cond. No.                         6.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Model including both Weekdays and Weather as controls for verification
# - To verify including Weekdays only is the best model that can strike a balance between generalabiltiy and statistical significance
# - With both weekdays and weather, F-stat in stage 1 drops to 3.414 and the p-value of `p_hat` in stage 2 increases

# %%
Z = df['p']
X = df[['Stormy', 'Mon', 'Tue', 'Wed', 'Thu', 'Cold', 'Rainy']]
X = sm.add_constant(X)
model = sm.OLS(Z,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      p   R-squared:                       0.188
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     3.414
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):            0.00254
# Time:                        15:43:17   Log-Likelihood:                -38.582
# No. Observations:                 111   AIC:                             93.16
# Df Residuals:                     103   BIC:                             114.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2902      0.082     -3.536      0.001      -0.453      -0.127
# Stormy         0.3127      0.082      3.823      0.000       0.150       0.475
# Mon           -0.1216      0.109     -1.120      0.265      -0.337       0.094
# Tue           -0.0567      0.107     -0.530      0.597      -0.269       0.155
# Wed           -0.0284      0.109     -0.261      0.794      -0.244       0.187
# Thu            0.0404      0.106      0.382      0.703      -0.169       0.250
# Cold           0.0810      0.074      1.089      0.279      -0.066       0.228
# Rainy         -0.0167      0.094     -0.179      0.858      -0.202       0.169
# ==============================================================================
# Omnibus:                        1.369   Durbin-Watson:                   0.606
# Prob(Omnibus):                  0.504   Jarque-Bera (JB):                1.442
# Skew:                          -0.224   Prob(JB):                        0.486
# Kurtosis:                       2.667   Cond. No.                         6.92
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
p_hat = model.predict(X)
df['p_hat'] = p_hat

# %%
Y = df['q']
X =  df[['p_hat', 'Mon', 'Tue', 'Wed', 'Thu', 'Cold', 'Rainy']]
X = sm.add_constant(X)
model= sm.OLS(Y,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      q   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     3.579
# Date:                Fri, 22 Sep 2023   Prob (F-statistic):            0.00173
# Time:                        15:43:19   Log-Likelihood:                -111.74
# No. Observations:                 111   AIC:                             239.5
# Df Residuals:                     103   BIC:                             261.2
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.4417      0.205     41.211      0.000       8.035       8.848
# p_hat         -1.2228      0.506     -2.418      0.017      -2.226      -0.220
# Mon           -0.0333      0.215     -0.155      0.877      -0.460       0.393
# Tue           -0.5328      0.209     -2.551      0.012      -0.947      -0.119
# Wed           -0.5756      0.211     -2.726      0.008      -0.994      -0.157
# Thu            0.1179      0.205      0.574      0.567      -0.289       0.525
# Cold           0.0681      0.164      0.415      0.679      -0.257       0.393
# Rainy          0.0720      0.181      0.399      0.691      -0.286       0.430
# ==============================================================================
# Omnibus:                       15.483   Durbin-Watson:                   1.540
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.339
# Skew:                          -0.799   Prob(JB):                     0.000104
# Kurtosis:                       4.189   Cond. No.                         10.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Sargan's test of overidentification

# %%
#Overidentification
mlr2 = lm.IV2SLS(dependent=df['q'], exog= None , endog=df['p'], instruments=df[['Stormy', 'Wind']]).fit(cov_type="homoskedastic", debiased=True)
mlr2.sargan
# Out:
# Sargan's test of overidentification
# H0: The model is not overidentified.
# Statistic: 24.6054
# P-value: 0.0000
# Distributed: chi2(1)
# WaldTestStatistic, id: 0x133949490

# %% [markdown]
# - We reject H0 as p-value <0.05, so having both `Stormy` and `Wind` results in overidentification
